# %% [markdown]
# # HOW-TO-RIPPLE-LEARNING-BENCHMARK
#
# Quest: Ripple Forge
# Belt target: Brown
#
# Goal:
# - test learn/propose/apply loop
# - verify externalized updates in Prime Mermaid
#
# Gate:
# - proposal artifact exists
# - apply step succeeds
# - resulting ripple is inspectable

# %%
from pathlib import Path

repo = Path.cwd().resolve()
while repo != repo.parent and not (repo / 'cli' / 'src').exists():
    repo = repo.parent
assert (repo / 'cli' / 'src').exists(), 'Repo root not found'

targets = [
    repo / 'skills' / 'phuc-forecast.md',
    repo / 'skills' / 'phuc-swarms.md',
    repo / 'skills' / 'prime-coder.md',
]
for t in targets:
    ok = t.exists()
    print(t, 'exists=' + str(ok))
    if not ok:
        raise RuntimeError('Missing required skill: ' + str(t))
