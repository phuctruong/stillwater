# %% [markdown]
# # Stillwater CLI Quickstart
#
# This notebook demonstrates basic stillwater/cli usage.

# %%
# Import stillwater CLI
from stillwater.cli import main
import sys

print('Stillwater CLI ready')

# %% [markdown]
# ## Running Commands
#
# Use the CLI to interact with your projects.

# %%
# Example: Get help
# sys.argv = ['stillwater', '--help']
# main()

print('CLI integration ready for your commands')
